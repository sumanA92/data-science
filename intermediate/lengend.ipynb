# %% [markdown]
# ### matplotlib.pyplot.legend(*args, **kwargs)

# %% [markdown]
# Place a legend on the axes.

# %% [markdown]
# Call signatures:

# %% [markdown]
# 1. __legend()__
# 2. __legend(labels)__
# 3. __legend(handles, labels)__

# %% [markdown]
# #### 1. Automatic detection of elements to be shown in the legend

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
ax.plot([1, 2, 3, 4], label='Inline label')
plt.legend()
plt.show()

# %% [markdown]
# or:

# %%
fig, ax = plt.subplots()
ax.plot([1, 2, 3, 4])
ax.set_label('Label via method')
plt.legend()
#ax.legend()  No legend for this also
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
fig, ax = plt.subplots()
line = ax.plot([1, 2, 3, 4])
ax.set_label('Label via method')
plt.legend(line)
plt.show()

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
ax.plot([1, 2, 3, 4], label='_Inline label')
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# __Specific lines can be excluded from the automatic legend element selection by defining a ``label starting with an underscore.``__This is default for all artists, so calling Axes.legend without any arguments and without setting the labels manually will result in no legend being drawn.

# %% [markdown]
# #### 2. Labeling existing plot elements

# %% [markdown]
# To make a legend for lines which already exist on the axes (via plot for instance), simply __call this function with an iterable of strings, one for each legend item__

# %%
fig, ax = plt.subplots()
ax.plot([1, 2, 3, 4])
ax.plot([4, 3, 2, 1])
ax.legend(['Increase line','Decrease line'])
plt.show()

# %% [markdown]
# > Note: This way of using is discouraged, because the relation between plot elements and labels is only implicit by their order and can easily be mixed up.

# %% [markdown]
# #### 3. Explicitly defining the elements in the legend

# %% [markdown]
# For full control of which artists have a legend entry, it is possible to pass an iterable of legend artists followed by an iterable of legend labels respectively:

# %%
fig, ax = plt.subplots()
line1, = ax.plot([1, 2, 3, 4])
line2, = ax.plot([4, 3, 2, 1])
ax.legend((line1, line2), ('Increase line','Decrease line'))
plt.show()

# %%
import numpy as np
data = np.arange(12).reshape(6, 2)

fig, ax = plt.subplots()
#line,l2, = ax.plot(data)
#plt.legend((line,l2), ['Increase line','Decrease line'])
lines = ax.plot(data)
plt.legend(lines, ['Increase line','Decrease line'])
#ax.legend(lines, ['Increase line','Decrease line'])

plt.show()

# %%
import numpy as np
data = np.arange(12).reshape(4,3)

fig, ax = plt.subplots()
ax.plot(data[0], data[1:])
plt.show()

# %% [markdown]
# #### Parameters:
# handles : sequence of Artist, optional
#
# labels : sequence of strings, optionalReturns:
#
# ##### Returns:
# matplotlib.legend.Legend instance
#
# ##### Other Parameters:
# __loc :__ str or pair of floats, default: rcParams["legend.loc"] ('best' for axes, 'upper right' for figures)
#
# The location of the legend.
#
# The string 'best' places the legend at the location, among the nine locations defined so far, with the minimum overlap with other drawn artists. This option can be quite slow for plots with large amounts of data; your plotting speed may benefit from providing a specific location.
#
# |Location String	|Location Code
# |---|---
# |'best'			|0
# |'upper right'	|1
# |'upper left'	|2
# |'lower left'	|3
# |'lower right'	|4
# |'right'	    | 5
# |'center left'	|6
# |'center right'	|7
# |'lower center'	|8
# |'upper center'	|9
# |'center'		|10
#
# __bbox_to_anchor :__ BboxBase, 2-tuple, or 4-tuple of floats
#
# Box that is used to position the legend in conjunction with loc.
#
# If a 4-tuple or BboxBase is given, then it specifies the bbox (x, y, width, height) that the legend is placed in. __To put the legend in the best location in the bottom right quadrant of the axes (or figure):__
#
# >loc='best', bbox_to_anchor=(0.5, 0., 0.5, 0.5)
#
# A __2-tuple (x, y) places the corner of the legend specified by loc at x, y.__ For example, to put the legend's upper right-hand corner in the center of the axes (or figure) the following keywords can be used:
#
# > loc='upper right', bbox_to_anchor=(0.5, 0.5)
#
# __ncol :__ integer - The number of columns that the legend has. Default is 1.
#
# __prop :__ None or matplotlib.font_manager.FontProperties or dict - The font properties of the legend
#
# __fontsize :__ int or float or {'xx-small', 'x-small', 'small', 'medium', 'large', 'x-large', 'xx-large'} - Controls the font size of the legend
#
# __numpoints :__ None or int
#
# The number of marker points in the legend when creating a legend entry for a Line2D (line). Default is None, which will take the value from rcParams["legend.numpoints"].
#
# __scatterpoints :__ None or int
#
# The number of marker points in the legend when creating a legend entry for a PathCollection (scatter plot). Default is None, which will take the value from rcParams["legend.scatterpoints"].
#
# __scatteryoffsets :__ iterable of floats
#
# The vertical offset (relative to the font size) for the markers created for a scatter plot legend entry. 0.0 is at the base the legend text, and 1.0 is at the top. To draw all markers at the same height, set to [0.5]. Default is [0.375, 0.5, 0.3125].
#
# __markerscale :__ None or int or float - The relative size of legend markers compared with the originally drawn ones
#
# __markerfirst :__ bool - If True, legend marker is placed to the left of the legend label. If False, legend marker is placed to the right of the legend label. Default is True.
#
# __frameon :__ None or bool - Control whether the legend should be drawn on a patch (frame).
#
# __fancybox :__ None or bool - Control whether round edges should be enabled around the FancyBboxPatch which makes up the legend's background.
#
# __shadow :__ None or bool - Control whether to draw a shadow behind the legend.
#
# __framealpha :__ None or float - Control the alpha transparency of the legend's background
#
# __facecolor :__ None or "inherit" or a color spec - Control the legend's background color.
#
# __edgecolor :__ None or "inherit" or a color spec - Control the legend's background patch edge color.
#
# __mode :__ {"expand", None} - If mode is set to "expand" the legend will be horizontally expanded to fill the axes area (or bbox_to_anchor if defines the legend's size).
#
# __bbox_transform :__ None or matplotlib.transforms.Transform - The transform for the bounding box (bbox_to_anchor).
#
# __title :__ str or None - The legend's title. Default is no title (None).
#
# __title_fontsize:__ str or None - The fontsize of the legend's title. Default is the default fontsize.
#
# __borderpad :__ float or None - The fractional whitespace inside the legend border.
#
# __labelspacing :__ float or None - The vertical space between the legend entries.
#
# __handlelength :__ float or None - The length of the legend handles.
#
# __handletextpad :__ float or None - The pad between the legend handle and text
#
# __borderaxespad :__ float or None - The pad between the axes and legend border.
#
# __columnspacing :__ float or None - The spacing between columns.
#
# __handler_map :__ dict or None - The custom dictionary mapping instances or types to a legend handler.

# %% [markdown]
# #### Legend using pre-defined labels

# %%
import numpy as np
import matplotlib.pyplot as plt

# Make some fake data.
a = b = np.arange(0, 3, .02)
c = np.exp(a)
d = c[::-1]

# Create plots with pre-defined labels.
fig, ax = plt.subplots()
ax.plot(a, c, 'k--', label='Model length')
ax.plot(a, d, 'k:', label='Data length')
ax.plot(a, c + d, 'k', label='Total message length')

legend = ax.legend(title='Legend title',loc='upper center', shadow=True, fontsize='x-large', edgecolor='yellow', 
                   borderaxespad=0, handletextpad=0)

# Put a nicer background color on the legend.
legend.get_frame().set_facecolor('lightblue')

plt.show()

# %% [markdown]
# #### New 0.98.4 Legend

# %%
import matplotlib.pyplot as plt
import numpy as np


ax = plt.subplot(111)
t1 = np.arange(0.0, 1.0, 0.01)
fmt=['or','^g','*y','1b']
for n in [1, 2, 3, 4]:
    plt.plot(t1, t1**n, fmt[n-1],label="n=%d"%(n,))

leg = plt.legend(loc='best', ncol=2, mode="expand", shadow=True, fancybox=True, markerfirst=False, numpoints=2)
leg.get_frame().set_alpha(0.5)


plt.show()
