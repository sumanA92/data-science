# %%
import pandas as pd

# %%
df=pd.read_csv("train.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
df['Age'].max()

# %%
df.Name[df['Survived']==0]
# Out:
# 0                                Braund, Mr. Owen Harris
# 4                               Allen, Mr. William Henry
# 5                                       Moran, Mr. James
# 6                                McCarthy, Mr. Timothy J
# 7                         Palsson, Master. Gosta Leonard
# 12                        Saundercock, Mr. William Henry
# 13                           Andersson, Mr. Anders Johan
# 14                  Vestrom, Miss. Hulda Amanda Adolfina
# 16                                  Rice, Master. Eugene
# 18     Vander Planke, Mrs. Julius (Emelia Maria Vande...
# 20                                  Fynney, Mr. Joseph J
# 24                         Palsson, Miss. Torborg Danira
# 26                               Emir, Mr. Farred Chehab
# 27                        Fortune, Mr. Charles Alexander
# 29                                   Todoroff, Mr. Lalio
# 30                              Uruchurtu, Don. Manuel E
# ...

# %%
df[['Name','Sex']][df['Survived']==0][df['Sex']=='female']# below solution gives best performance
# Out:
# E:\Study\ML\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#                                                   Name     Sex
# 14                Vestrom, Miss. Hulda Amanda Adolfina  female
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female
# 24                       Palsson, Miss. Torborg Danira  female
# 38                  Vander Planke, Miss. Augusta Maria  female
# 40      Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  female
# 41   Turpin, Mrs. William John Robert (Dorothy Ann ...  female
# 49       Arnold-Franchi, Mrs. Josef (Josefine Franchi)  female
# 71                          Goodwin, Miss. Lillian Amy  female
# 100                            Petranec, Miss. Matilda  female
# 111                               Zabour, Miss. Hileni  female
# 113                            Jussila, Miss. Katriina  female
# ...

# %%
df[['Name','Sex']][(df['Survived']==0)&(df['Sex']=='female')]
# Out:
#                                                   Name     Sex
# 14                Vestrom, Miss. Hulda Amanda Adolfina  female
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female
# 24                       Palsson, Miss. Torborg Danira  female
# 38                  Vander Planke, Miss. Augusta Maria  female
# 40      Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  female
# 41   Turpin, Mrs. William John Robert (Dorothy Ann ...  female
# 49       Arnold-Franchi, Mrs. Josef (Josefine Franchi)  female
# 71                          Goodwin, Miss. Lillian Amy  female
# 100                            Petranec, Miss. Matilda  female
# 111                               Zabour, Miss. Hileni  female
# 113                            Jussila, Miss. Katriina  female
# 114                              Attalah, Miss. Malake  female
# 119                  Andersson, Miss. Ellis Anna Maria  female
# 132     Robins, Mrs. Alexander A (Grace Charity Laury)  female
# ...

# %%
select max(slary) from emp where salary < select max(salary) from emp

# %%
df['Name'][(df['Survived']==0) & (df['Sex']=='female') & (df['Embarked']=='C')]
# Out:
# 111                Zabour, Miss. Hileni
# 114               Attalah, Miss. Malake
# 140       Boulos, Mrs. Joseph (Sultana)
# 177          Isham, Miss. Ann Elizabeth
# 240               Zabour, Miss. Thamine
# 362     Barbara, Mrs. (Catherine David)
# 578    Caram, Mrs. Joseph (Maria Elias)
# 702               Barbara, Miss. Saiide
# 852             Boulos, Miss. Nourelain
# Name: Name, dtype: object

# %%
df2=pd.read_csv('train.csv',nrows=10)

# %%
df2
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
df3=pd.read_csv('train.csv',nrows=4,skiprows=1,header=None)

# %%
df3
# Out:
#    0   1   2                                                  3       4   5   \
# 0   1   0   3                            Braund, Mr. Owen Harris    male  22
# 1   2   1   1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38
# 2   3   1   3                             Heikkinen, Miss. Laina  female  26
# 3   4   1   1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35
#
#    6   7                 8        9     10 11
# 0   1   0         A/5 21171   7.2500   NaN  S
# 1   1   0          PC 17599  71.2833   C85  C
# 2   0   0  STON/O2. 3101282   7.9250   NaN  S
# 3   1   0            113803  53.1000  C123  S

# %%
pd.read_csv('train.csv',nrows=10,skiprows=3,header=None)
# Out:
#    0   1   2                                                  3       4   \
# 0   3   1   3                             Heikkinen, Miss. Laina  female
# 1   4   1   1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 2   5   0   3                           Allen, Mr. William Henry    male
# 3   6   0   3                                   Moran, Mr. James    male
# 4   7   0   1                            McCarthy, Mr. Timothy J    male
# 5   8   0   3                     Palsson, Master. Gosta Leonard    male
# 6   9   1   3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female
# 7  10   1   2                Nasser, Mrs. Nicholas (Adele Achem)  female
# 8  11   1   3                    Sandstrom, Miss. Marguerite Rut  female
# 9  12   1   1                           Bonnell, Miss. Elizabeth  female
#
#      5   6   7                 8        9     10 11
# 0  26.0   0   0  STON/O2. 3101282   7.9250   NaN  S
# 1  35.0   1   0            113803  53.1000  C123  S
# ...

# %%
pd.read_csv('train.csv',nrows=10,skiprows=1,header=1)
# Out:
#     2  1  1.1 Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  \
# 0   3  1    3                             Heikkinen, Miss. Laina   female
# 1   4  1    1       Futrelle, Mrs. Jacques Heath (Lily May Peel)   female
# 2   5  0    3                           Allen, Mr. William Henry     male
# 3   6  0    3                                   Moran, Mr. James     male
# 4   7  0    1                            McCarthy, Mr. Timothy J     male
# 5   8  0    3                     Palsson, Master. Gosta Leonard     male
# 6   9  1    3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)   female
# 7  10  1    2                Nasser, Mrs. Nicholas (Adele Achem)   female
# 8  11  1    3                    Sandstrom, Miss. Marguerite Rut   female
# 9  12  1    1                           Bonnell, Miss. Elizabeth   female
#
#      38  1.2  0          PC 17599  71.2833   C85  C
# 0  26.0    0  0  STON/O2. 3101282   7.9250   NaN  S
# ...

# %%
pd.read_csv('train.csv',nrows=10,skiprows=1,header=0)
# Out:
#     1  0  3                            Braund, Mr. Owen Harris    male    22  \
# 0   2  1  1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 1   3  1  3                             Heikkinen, Miss. Laina  female  26.0
# 2   4  1  1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 3   5  0  3                           Allen, Mr. William Henry    male  35.0
# 4   6  0  3                                   Moran, Mr. James    male   NaN
# 5   7  0  1                            McCarthy, Mr. Timothy J    male  54.0
# 6   8  0  3                     Palsson, Master. Gosta Leonard    male   2.0
# 7   9  1  3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 8  10  1  2                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
# 9  11  1  3                    Sandstrom, Miss. Marguerite Rut  female   4.0
#
#    1.1  0.1         A/5 21171     7.25 Unnamed: 10  S
# 0    1    0          PC 17599  71.2833         C85  C
# ...

# %%
pd.read_csv('train.csv',nrows=10,names=['ID','NAMES','SEX'])
# Out:
#                                                                                                                              ID  \
# PassengerId Survived Pclass Name                                               Sex    Age SibSp Parch Ticket               Fare
# 1           0        3      Braund, Mr. Owen Harris                            male   22  1     0     A/5 21171            7.25
# 2           1        1      Cumings, Mrs. John Bradley (Florence Briggs Tha... female 38  1     0     PC 17599          71.2833
# 3           1        3      Heikkinen, Miss. Laina                             female 26  0     0     STON/O2. 3101282    7.925
# 4           1        1      Futrelle, Mrs. Jacques Heath (Lily May Peel)       female 35  1     0     113803               53.1
# 5           0        3      Allen, Mr. William Henry                           male   35  0     0     373450               8.05
# ...

# %%
help(pd.read_csv)
# Out:
# Help on function read_csv in module pandas.io.parsers:
#
# read_csv(filepath_or_buffer, sep=',', delimiter=None, header='infer', names=None, index_col=None, usecols=None, squeeze=False, prefix=None, mangle_dupe_cols=True, dtype=None, engine=None, converters=None, true_values=None, false_values=None, skipinitialspace=False, skiprows=None, nrows=None, na_values=None, keep_default_na=True, na_filter=True, verbose=False, skip_blank_lines=True, parse_dates=False, infer_datetime_format=False, keep_date_col=False, date_parser=None, dayfirst=False, iterator=False, chunksize=None, compression='infer', thousands=None, decimal=b'.', lineterminator=None, quotechar='"', quoting=0, escapechar=None, comment=None, encoding=None, dialect=None, tupleize_cols=None, error_bad_lines=True, warn_bad_lines=True, skipfooter=0, doublequote=True, delim_whitespace=False, low_memory=True, memory_map=False, float_precision=None)
#     Read CSV (comma-separated) file into DataFrame
#
# ...

# %%
pd.read_csv('train without header.csv',nrows=3,names=['ID','NAMES','SEX'])

# %%
df_noheaders=pd.read_csv('train.csv',nrows=10)

# %%
df_noheaders.to_csv('write file.csv')

# %%
df_noheaders.to_csv('write file2.csv',nrows=3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-b39bf602d2a1> in <module>
# ----> 1 df_noheaders.to_csv('write file2.csv',nrows=3)
#
# TypeError: to_csv() got an unexpected keyword argument 'nrows'

# %%
df_noheaders.to_csv('write file2.csv',header=False)

# %%
df_noheaders.to_csv('write file3.csv',header=False,index=False)

# %%
df_noheaders.to_csv('write file4.csv',index=False,columns=['Name','Sex'])

# %%
df_new=df[(df['Survived']==0) & (df['Age'] > 30) & (df['Embarked']=='C')]

# %%
df_new
# Out:
#      PassengerId  Survived  Pclass                             Name     Sex  \
# 30            31         0       1         Uruchurtu, Don. Manuel E    male
# 54            55         0       1   Ostby, Mr. Engelhart Cornelius    male
# 96            97         0       1        Goldschmidt, Mr. George B    male
# 122          123         0       2             Nasser, Mr. Nicholas    male
# 130          131         0       3             Drazenoic, Mr. Jozef    male
# 155          156         0       1      Williams, Mr. Charles Duane    male
# 174          175         0       1          Smith, Mr. James Clinch    male
# 177          178         0       1       Isham, Miss. Ann Elizabeth  female
# 203          204         0       3             Youseff, Mr. Gerious    male
# 273          274         0       1            Natsch, Mr. Charles H    male
# 285          286         0       3              Stankovic, Mr. Ivan    male
# ...

# %%
df_new.to_csv('young passengers.csv',columns=['Passenger',"Age"])

# %%
df_new.to_excel('young passengers.xls',index=False,columns=['Name',"Age","Passenger"])

# %%
# %pwd
# Out:
# 'C:\\Users\\suman\\Pandas'

# %%
out=df.groupby('Embarked')

# %%
out

# %%
for i,j in out:
    print(i)
    print(j)
# Out:
# C
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 9             10         1       2
# 19            20         1       3
# 26            27         0       3
# 30            31         0       1
# 31            32         1       1
# 34            35         0       1
# 36            37         1       3
# 39            40         1       3
# 42            43         0       3
# 43            44         1       2
# 48            49         0       3
# 52            53         1       1
# 54            55         0       1
# 57            58         0       3
# 60            61         0       3
# 64            65         0       1
# 65            66         1       3
# 73            74         0       3
# 96            97         0       1
# 97            98         1       1
# 111          112         0       3
# 114          115         0       3
# 118          119         0       1
# 122          123         0       2
# ...

# %%
data={'S.No.':[1,2,3,4,5],'Name':['S1','S2','S3','s4','s5'],"Marks":[60,50,30,40,70],"Department":['T1','D1','T1','D2','T1']}

# %%
df_map=pd.DataFrame(data)

# %%
dept=df_map.groupby(['Department',"Name"])

# %%
dept

# %%
for i,j in dept:
    print(i)
    print(j)
# Out:
# ('D1', 'S2')
#    S.No. Name  Marks Department
# 1      2   S2     50         D1
# ('D2', 's4')
#    S.No. Name  Marks Department
# 3      4   s4     40         D2
# ('T1', 'S1')
#    S.No. Name  Marks Department
# 0      1   S1     60         T1
# ('T1', 'S3')
#    S.No. Name  Marks Department
# 2      3   S3     30         T1
# ('T1', 's5')
#    S.No. Name  Marks Department
# 4      5   s5     70         T1

# %%
dept=df_map.groupby(['Department']) #dept=df_map.groupby('Department')

# %%
for i,j in dept:
    print(i)
    print(j)
# Out:
# D1
#    S.No. Name  Marks Department
# 1      2   S2     50         D1
# D2
#    S.No. Name  Marks Department
# 3      4   s4     40         D2
# T1
#    S.No. Name  Marks Department
# 0      1   S1     60         T1
# 2      3   S3     30         T1
# 4      5   s5     70         T1

# %%
dept.get_group('T1')
# Out:
#    S.No. Name  Marks Department
# 0      1   S1     60         T1
# 2      3   S3     30         T1
# 4      5   s5     70         T1

# %%
dept1=dept.get_group('T1').max()

# %%
dept1
# Out:
# S.No.          5
# Name          s5
# Marks         70
# Department    T1
# dtype: object

# %%
dept1=dept.
